# %%
# Import the Pandas library


import sys

sys.path.append('../')

from models.tensorflow_model import TensorFlowModel

model = TensorFlowModel()
path = "../test_data/more_data.xlsx"

coded_df = model.process_excel(path)


print(coded_df.info())
coded_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42380 entries, 0 to 42379
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   NAME                 42380 non-null  object
#  1   date                 42380 non-null  int64
#  2   color_and_value      42380 non-null  object
#  3   name_code            42380 non-null  int64
#  4   day_of_month         42380 non-null  int32
#  5   day_of_week          42380 non-null  int32
#  6   date_code            42380 non-null  int64
#  7   day_of_year          42380 non-null  int64
#  8   value                42380 non-null  float64
#  9   color                42380 non-null  object
#  10  extra                42380 non-null  float64
#  11  color_code           42380 non-null  int64
#  12  next_color_code      42250 non-null  float64
#  13  previous_color_code  42250 non-null  float64
#  14  color_binary         42380 non-null  int64
#  15  next_color_binary    42250 non-null  float64
# dtypes: float64(5), int32(2), int64(6), object(3)
# memory usage: 4.9+ MB
# None
#         NAME                 date                  color_and_value  name_code  \
# 0        GJ1  1672185600000000000   19.1379 | FFFF00 | 193873167.0          1
# 1        GJ2  1672185600000000000  44.45609 | FFFF00 | 230529712.0          2
# 2        GJ3  1672185600000000000    65.52176 | A9D08E | 1377950.0          3
# 3        GJ4  1672185600000000000    28.03879 | FFFF00 | 3624974.0          4
# 4        GJ5  1672185600000000000     12.66648 | 9BC2E6 | 313366.0          5
# ...      ...                  ...                              ...        ...
# 42375  GJ132  1713916800000000000        19.17218 | A9D08E | 98713        132
# 42376  GJ133  1713916800000000000      -27.1069 | FFFF00 | 1287615        133
# 42377  GJ134  1713916800000000000       14.05361 | FFC000 | 175334        134
# 42378  GJ135  1713916800000000000      -5.21327 | FFFF00 | 1185359        135
# 42379  GJ136  1713916800000000000      51.27713 | A9D08E | 4555962        136
#
#        day_of_month  day_of_week  date_code  day_of_year     value   color  \
# 0                28            2          0          362  19.13790  FFFF00
# 1                28            2          0          362  44.45609  FFFF00
# 2                28            2          0          362  65.52176  A9D08E
# 3                28            2          0          362  28.03879  FFFF00
# 4                28            2          0          362  12.66648  9BC2E6
# ...             ...          ...        ...          ...       ...     ...
# 42375            24            2        325          115  19.17218  A9D08E
# 42376            24            2        325          115 -27.10690  FFFF00
# 42377            24            2        325          115  14.05361  FFC000
# 42378            24            2        325          115  -5.21327  FFFF00
# 42379            24            2        325          115  51.27713  A9D08E
#
#              extra  color_code  next_color_code  previous_color_code  \
# 0      193873167.0           0              2.0                  NaN
# 1      230529712.0           0              3.0                  NaN
# 2        1377950.0           1              1.0                  NaN
# 3        3624974.0           0              1.0                  NaN
# 4         313366.0           2              2.0                  NaN
# ...            ...         ...              ...                  ...
# 42375      98713.0           1              NaN                  1.0
# 42376    1287615.0           0              NaN                  0.0
# 42377     175334.0           3              NaN                  0.0
# 42378    1185359.0           0              NaN                  1.0
# 42379    4555962.0           1              NaN                  1.0
#
#        color_binary  next_color_binary
# 0                 0                1.0
# 1                 0                1.0
# 2                 0                0.0
# 3                 0                0.0
# 4                 1                1.0
# ...             ...                ...
# 42375             0                NaN
# 42376             0                NaN
# 42377             1                NaN
# 42378             0                NaN
# 42379             0                NaN
#
# [42380 rows x 16 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split



# Splitting the dataset into the Training set and Test set
X, y= model.train_test_split(coded_df)

X.shape , y.shape
# Out:
# ((42120, 8), (42120,))

# %%
model.fit(X, y)

print(f'mse : {model.mse}' )
print(f'accuracy: {model.accuracy}' )
print(f'preferred_accuracy: {model.preferred_accuracy}' )

print(f'predictions_count: {model.predictions_count}   in {model.y_test_count}' )


prob = coded_df[coded_df['color_binary'] == 1].shape[0] / coded_df.shape[0]

print(f'real prob: {prob}' )
# Out:
# Epoch 1/30
# 2024-08-08 13:53:55.249449: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-08-08 13:53:55.251735: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 1053/1053 [==============================] - 2s 1ms/step - loss: 0.6839 - accuracy: 0.5505
# Epoch 2/30
# 1053/1053 [==============================] - 1s 1ms/step - loss: 0.6800 - accuracy: 0.5597
# Epoch 3/30
# 1053/1053 [==============================] - 1s 1ms/step - loss: 0.6797 - accuracy: 0.5646
# Epoch 4/30
# 1053/1053 [==============================] - 1s 1ms/step - loss: 0.6770 - accuracy: 0.5684
# Epoch 5/30
# 1053/1053 [==============================] - 1s 1ms/step - loss: 0.6769 - accuracy: 0.5672
# Epoch 6/30
# 1053/1053 [==============================] - 1s 1ms/step - loss: 0.6760 - accuracy: 0.5690
# Epoch 7/30
# 1053/1053 [==============================] - 1s 1ms/step - loss: 0.6747 - accuracy: 0.5749
# Epoch 8/30
# 1053/1053 [==============================] - 1s 1ms/step - loss: 0.6738 - accuracy: 0.5718
# Epoch 9/30
# 1053/1053 [==============================] - 1s 1ms/step - loss: 0.6733 - accuracy: 0.5748
# Epoch 10/30
# 1053/1053 [==============================] - 1s 1ms/step - loss: 0.6726 - accuracy: 0.5749
# Epoch 11/30
# 1053/1053 [==============================] - 1s 1ms/step - loss: 0.6727 - accuracy: 0.5782
# Epoch 12/30
# 1053/1053 [==============================] - 1s 1ms/step - loss: 0.6709 - accuracy: 0.5764
# Epoch 13/30
# 1053/1053 [==============================] - 1s 1ms/step - loss: 0.6721 - accuracy: 0.5758
# Epoch 14/30
# 1053/1053 [==============================] - 1s 1ms/step - loss: 0.6702 - accuracy: 0.5770
# Epoch 15/30
# 1053/1053 [==============================] - 1s 999us/step - loss: 0.6711 - accuracy: 0.5794
# Epoch 16/30
# 1053/1053 [==============================] - 1s 1ms/step - loss: 0.6709 - accuracy: 0.5805
# Epoch 17/30
# 1053/1053 [==============================] - 1s 999us/step - loss: 0.6706 - accuracy: 0.5793
# Epoch 18/30
# 1053/1053 [==============================] - 1s 1ms/step - loss: 0.6703 - accuracy: 0.5801
# Epoch 19/30
# 1053/1053 [==============================] - 1s 1ms/step - loss: 0.6699 - accuracy: 0.5796
# Epoch 20/30
# 1053/1053 [==============================] - 1s 1ms/step - loss: 0.6695 - accuracy: 0.5796
# Epoch 21/30
# 1053/1053 [==============================] - 1s 1ms/step - loss: 0.6693 - accuracy: 0.5824
# Epoch 22/30
# 1053/1053 [==============================] - 1s 1ms/step - loss: 0.6690 - accuracy: 0.5829
# Epoch 23/30
# 1053/1053 [==============================] - 1s 1ms/step - loss: 0.6689 - accuracy: 0.5804
# Epoch 24/30
# 1053/1053 [==============================] - 1s 1ms/step - loss: 0.6695 - accuracy: 0.5800
# Epoch 25/30
# 1053/1053 [==============================] - 1s 1ms/step - loss: 0.6686 - accuracy: 0.5830
# Epoch 26/30
# 1053/1053 [==============================] - 1s 987us/step - loss: 0.6687 - accuracy: 0.5839
# Epoch 27/30
# 1053/1053 [==============================] - 1s 1ms/step - loss: 0.6681 - accuracy: 0.5836
# Epoch 28/30
# 1053/1053 [==============================] - 1s 991us/step - loss: 0.6686 - accuracy: 0.5826
# Epoch 29/30
# 1053/1053 [==============================] - 1s 981us/step - loss: 0.6693 - accuracy: 0.5804
# Epoch 30/30
# 1053/1053 [==============================] - 1s 995us/step - loss: 0.6685 - accuracy: 0.5825
# 264/264 [==============================] - 0s 667us/step
# Epoch 1/30
# 264/264 [==============================] - 1s 2ms/step - loss: 0.6690 - accuracy: 0.5757
# Epoch 2/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6700 - accuracy: 0.5773
# Epoch 3/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6686 - accuracy: 0.5812
# Epoch 4/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6693 - accuracy: 0.5744
# Epoch 5/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6708 - accuracy: 0.5817
# Epoch 6/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6681 - accuracy: 0.5770
# Epoch 7/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6694 - accuracy: 0.5723
# Epoch 8/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6685 - accuracy: 0.5737
# Epoch 9/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6687 - accuracy: 0.5694
# Epoch 10/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6678 - accuracy: 0.5749
# Epoch 11/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6692 - accuracy: 0.5748
# Epoch 12/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6682 - accuracy: 0.5704
# Epoch 13/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6667 - accuracy: 0.5787
# Epoch 14/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6670 - accuracy: 0.5788
# Epoch 15/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6662 - accuracy: 0.5762
# Epoch 16/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6698 - accuracy: 0.5760
# Epoch 17/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6668 - accuracy: 0.5792
# Epoch 18/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6667 - accuracy: 0.5826
# Epoch 19/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6663 - accuracy: 0.5757
# Epoch 20/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6664 - accuracy: 0.5806
# Epoch 21/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6659 - accuracy: 0.5787
# Epoch 22/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6659 - accuracy: 0.5741
# Epoch 23/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6671 - accuracy: 0.5800
# Epoch 24/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6645 - accuracy: 0.5800
# Epoch 25/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6661 - accuracy: 0.5787
# Epoch 26/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6664 - accuracy: 0.5763
# Epoch 27/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6653 - accuracy: 0.5742
# Epoch 28/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6662 - accuracy: 0.5761
# Epoch 29/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6645 - accuracy: 0.5797
# Epoch 30/30
# 264/264 [==============================] - 0s 1ms/step - loss: 0.6650 - accuracy: 0.5743
# mse : 0.4666429249762583
# accuracy: 0.5333570750237417
# preferred_accuracy: 0.7073938122705821
# predictions_count: 1907   in 4722
# real prob: 0.5565361019348749

# %%
df =model.predict_last()
df
# Out:
# 5/5 [==============================] - 0s 1ms/step
#       NAME            2024-04-24 00:00:00                color_and_value  \
# 0      GJ1  2.166186 | FFFF00 | 231520813  2.166186 | FFFF00 | 231520813
# 1      GJ2  3.942408 | FFFF00 | 141110604  3.942408 | FFFF00 | 141110604
# 2      GJ3    5.464429 | A9D08E | 1654272    5.464429 | A9D08E | 1654272
# 3      GJ4    1.083493 | FFFF00 | 3847872    1.083493 | FFFF00 | 3847872
# 4      GJ5     14.56136 | A9D08E | 217146     14.56136 | A9D08E | 217146
# ..     ...                            ...                            ...
# 125  GJ132      19.17218 | A9D08E | 98713      19.17218 | A9D08E | 98713
# 126  GJ133    -27.1069 | FFFF00 | 1287615    -27.1069 | FFFF00 | 1287615
# 127  GJ134     14.05361 | FFC000 | 175334     14.05361 | FFC000 | 175334
# 128  GJ135    -5.21327 | FFFF00 | 1185359    -5.21327 | FFFF00 | 1185359
# 129  GJ136    51.27713 | A9D08E | 4555962    51.27713 | A9D08E | 4555962
#
#      next_color_code
# 0           0.504192
# 1           0.509274
# 2           0.522186
# 3           0.515835
# 4           0.523060
# ..               ...
# 125         0.517667
# 126         0.516370
# 127         0.602630
# 128         0.516351
# 129         0.517568
#
# [130 rows x 4 columns]

# %%
print(df[(df['next_color_code'] != 0)  ].shape)
df[(df['next_color_code'] != 0) ]
df.sort_values(by='next_color_code', ascending=False)[:40]
# Out:
# (130, 4)
#       NAME             2024-04-24 00:00:00                 color_and_value  \
# 111  GJ117  24.30198 | 8EA9DB | 2720000000  24.30198 | 8EA9DB | 2720000000
# 104  GJ108     55.48429 | D5A6BD | 1321429     55.48429 | D5A6BD | 1321429
# 91    GJ94      53.19525 | D5A6BD | 259805      53.19525 | D5A6BD | 259805
# 78    GJ81     33.65664 | D5A6BD | 1419210     33.65664 | D5A6BD | 1419210
# 56    GJ58      11.90044 | D5A6BD | 450921      11.90044 | D5A6BD | 450921
# 29    GJ30     31.96514 | D5A6BD | 1755588     31.96514 | D5A6BD | 1755588
# 23    GJ24      20.4325 | D5A6BD | 6154126      20.4325 | D5A6BD | 6154126
# 13    GJ14     4.730817 | D5A6BD | 1031497     4.730817 | D5A6BD | 1031497
# 44    GJ46    28.26433 | FFC000 | 30295177    28.26433 | FFC000 | 30295177
# 55    GJ57    74.41976 | FFC000 | 31008521    74.41976 | FFC000 | 31008521
# 54    GJ56    81.94723 | FFC000 | 27144053    81.94723 | FFC000 | 27144053
# 73    GJ76      13.246 | FFC000 | 10392195      13.246 | FFC000 | 10392195
# 74    GJ77       24.37793 | FFC000 | 51227       24.37793 | FFC000 | 51227
# 77    GJ80      0.892723 | FFC000 | 894176      0.892723 | FFC000 | 894176
# 81    GJ84      18.04918 | FFC000 | 366331      18.04918 | FFC000 | 366331
# 94    GJ97    244.9867 | FFC000 | 11816994    244.9867 | FFC000 | 11816994
# 88    GJ91      8.683868 | FFC000 | 503657      8.683868 | FFC000 | 503657
# 96   GJ100    76.27117 | FFC000 | 13558545    76.27117 | FFC000 | 13558545
# 97   GJ101     11.62803 | FFC000 | 1223564     11.62803 | FFC000 | 1223564
# 100  GJ104      9.260609 | FFC000 | 680331      9.260609 | FFC000 | 680331
# 110  GJ116     26.47896 | FFC000 | 3049206     26.47896 | FFC000 | 3049206
# 120  GJ126     74.8832 | FFC000 | 27662734     74.8832 | FFC000 | 27662734
# 124  GJ131     49.15563 | FFC000 | 1014238     49.15563 | FFC000 | 1014238
# 127  GJ134      14.05361 | FFC000 | 175334      14.05361 | FFC000 | 175334
# 122  GJ129      6.120847 | 8EA9DB | 260533      6.120847 | 8EA9DB | 260533
# 116  GJ122     37.13155 | 8EA9DB | 2926476     37.13155 | 8EA9DB | 2926476
# 109  GJ115      47.12953 | 8EA9DB | 635621      47.12953 | 8EA9DB | 635621
# 102  GJ106      -6.34129 | 8EA9DB | 294332      -6.34129 | 8EA9DB | 294332
# 99   GJ103      1.531112 | 8EA9DB | 635033      1.531112 | 8EA9DB | 635033
# 70    GJ72    37.40258 | 8EA9DB | 19202860    37.40258 | 8EA9DB | 19202860
# 90    GJ93     -7.27527 | 8EA9DB | 2550313     -7.27527 | 8EA9DB | 2550313
# 89    GJ92      19.59873 | 8EA9DB | 646643      19.59873 | 8EA9DB | 646643
# 72    GJ75    8.659538 | 8EA9DB | 12491248    8.659538 | 8EA9DB | 12491248
# 86    GJ89      40.11036 | 8EA9DB | 316601      40.11036 | 8EA9DB | 316601
# 82    GJ85     18.85547 | 8EA9DB | 1271123     18.85547 | 8EA9DB | 1271123
# 79    GJ82      3.133783 | 8EA9DB | 596378      3.133783 | 8EA9DB | 596378
# 60    GJ62     3.657036 | 8EA9DB | 9131403     3.657036 | 8EA9DB | 9131403
# 66    GJ68     0.778095 | 8EA9DB | 1566160     0.778095 | 8EA9DB | 1566160
# 63    GJ65     -8.24271 | 8EA9DB | 3056268     -8.24271 | 8EA9DB | 3056268
# 61    GJ63      -15.0059 | 8EA9DB | 507115      -15.0059 | 8EA9DB | 507115
#
#      next_color_code
# 111         0.999998
# 104         0.674252
# 91          0.674237
# 78          0.674215
# 56          0.674142
# 29          0.673387
# 23          0.673242
# 13          0.672815
# 44          0.646920
# 55          0.644148
# 54          0.643986
# 73          0.635176
# 74          0.633560
# 77          0.632575
# 81          0.631446
# 94          0.631260
# 88          0.629542
# 96          0.628632
# 97          0.626207
# 100         0.624979
# 110         0.618521
# 120         0.614764
# 124         0.605800
# 127         0.602630
# 122         0.548495
# 116         0.548452
# 109         0.547897
# 102         0.547086
# 99          0.546971
# 70          0.546831
# 90          0.546511
# 89          0.546427
# 72          0.546357
# 86          0.546327
# 82          0.546092
# 79          0.545811
# 60          0.545377
# 66          0.545116
# 63          0.545028
# 61          0.544697

# %%
model.save()

# %%
tf = TensorFlowModel()

# %%
tf.load()

# %%
coded_tf = tf.process_excel(path)
print(coded_tf.info())
coded_tf

# %%
# Splitting the dataset into the Training set and Test set
X, y= tf.train_test_split(coded_df)

X.shape , y.shape

# %%
tf.fit(X, y)

print(f'mse : {tf.mse}' )
print(f'accuracy: {tf.accuracy}' )
print(f'preferred_accuracy: {tf.preferred_accuracy}' )

print(f'predictions_count: {tf.predictions_count}   in {tf.y_test_count}' )


prob = coded_df[coded_df['color_binary'] == 1].shape[0] / coded_df.shape[0]

print(f'real prob: {prob}' )

# %%
df =tf.predict_last()
df
