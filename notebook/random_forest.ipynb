# %%
# Import the Pandas library


import sys

sys.path.append('../')

from models.random_forest import RandomForest

model = RandomForest()
path = "../.test_data/more_data.xlsx"

coded_df = model.process_excel(path)


print(coded_df.info())
coded_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42380 entries, 0 to 42379
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   NAME                 42380 non-null  object
#  1   date                 42380 non-null  int64
#  2   color_and_value      42380 non-null  object
#  3   name_code            42380 non-null  int64
#  4   day_of_month         42380 non-null  int32
#  5   day_of_week          42380 non-null  int32
#  6   date_code            42380 non-null  int64
#  7   day_of_year          42380 non-null  int64
#  8   value                42380 non-null  float64
#  9   color                42380 non-null  object
#  10  extra                42380 non-null  float64
#  11  color_code           42380 non-null  int64
#  12  next_color_code      42250 non-null  float64
#  13  previous_color_code  42250 non-null  float64
#  14  color_binary         42380 non-null  int64
#  15  next_color_binary    42250 non-null  float64
# dtypes: float64(5), int32(2), int64(6), object(3)
# memory usage: 4.9+ MB
# None
#         NAME                 date                  color_and_value  name_code  \
# 0        GJ1  1735257600000000000  28.26107 | A9D08E | 214257094.0          1
# 1        GJ2  1735257600000000000  47.95346 | A9D08E | 229631139.0          2
# 2        GJ3  1735257600000000000    78.28529 | 9BC2E6 | 1804911.0          3
# 3        GJ4  1735257600000000000    47.75716 | A9D08E | 4872234.0          4
# 4        GJ5  1735257600000000000     16.25788 | A9D08E | 226485.0          5
# ...      ...                  ...                              ...        ...
# 42375  GJ132  1713830400000000000       24.86704 | A9D08E | 459557        132
# 42376  GJ133  1713830400000000000      -17.7025 | FFFF00 | 2061010        133
# 42377  GJ134  1713830400000000000       16.26354 | FFFF00 | 299488        134
# 42378  GJ135  1713830400000000000      7.504595 | A9D08E | 1200666        135
# 42379  GJ136  1713830400000000000      55.14601 | A9D08E | 4657549        136
#
#        day_of_month  day_of_week  date_code  day_of_year      value   color  \
# 0                27            4          0          362  28.261070  A9D08E
# 1                27            4          0          362  47.953460  A9D08E
# 2                27            4          0          362  78.285290  9BC2E6
# 3                27            4          0          362  47.757160  A9D08E
# 4                27            4          0          362  16.257880  A9D08E
# ...             ...          ...        ...          ...        ...     ...
# 42375            23            1        325          114  24.867040  A9D08E
# 42376            23            1        325          114 -17.702500  FFFF00
# 42377            23            1        325          114  16.263540  FFFF00
# 42378            23            1        325          114   7.504595  A9D08E
# 42379            23            1        325          114  55.146010  A9D08E
#
#              extra  color_code  next_color_code  previous_color_code  \
# 0      214257094.0           0              3.0                  NaN
# 1      229631139.0           0              3.0                  NaN
# 2        1804911.0           1              0.0                  NaN
# 3        4872234.0           0              3.0                  NaN
# 4         226485.0           0              1.0                  NaN
# ...            ...         ...              ...                  ...
# 42375     459557.0           0              NaN                  2.0
# 42376    2061010.0           3              NaN                  3.0
# 42377     299488.0           3              NaN                  0.0
# 42378    1200666.0           0              NaN                  3.0
# 42379    4657549.0           0              NaN                  2.0
#
#        color_binary  next_color_binary
# 0                 0                0.0
# 1                 0                0.0
# 2                 1                0.0
# 3                 0                0.0
# 4                 0                1.0
# ...             ...                ...
# 42375             0                NaN
# 42376             0                NaN
# 42377             0                NaN
# 42378             0                NaN
# 42379             0                NaN
#
# [42380 rows x 16 columns]

# %%
coded_df['color'].factorize()
# Out:
# (array([0, 0, 1, ..., 3, 0, 0]),
#  Index(['A9D08E', '9BC2E6', 'FFC000', 'FFFF00', 'D5A6BD', 'FF0000', '8EA9DB'], dtype='object'))

# %%
model.last_df
# Out:
#       NAME            2024-04-23 00:00:00
# 0      GJ1  15.16266 | FFFF00 | 279259571
# 1      GJ2  12.20255 | A9D08E | 177719481
# 2      GJ3     5.246354 | FFFF00 | 993929
# 3      GJ4    3.574794 | FFFF00 | 8903130
# 4      GJ5     13.85017 | A9D08E | 197001
# ..     ...                            ...
# 125  GJ132     24.86704 | A9D08E | 459557
# 126  GJ133    -17.7025 | FFFF00 | 2061010
# 127  GJ134     16.26354 | FFFF00 | 299488
# 128  GJ135    7.504595 | A9D08E | 1200666
# 129  GJ136    55.14601 | A9D08E | 4657549
#
# [130 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split



# Splitting the dataset into the Training set and Test set
X, y = model.train_test_split(coded_df)


X.shape, y.shape
# Out:
# ((42120, 8), (42120,))

# %%
model.fit(X, y)

print(f'mse : {model.mse}' )
print(f'accuracy: {model.accuracy}' )
print(f'preferred_accuracy: {model.preferred_accuracy}' )

print(f'predictions_count: {model.predictions_count}   in {model.y_test_count}' )


prob = coded_df[coded_df['color_binary'] == 1].shape[0] / coded_df.shape[0]

print(f'real prob: {prob}' )
# Out:
# mse : 0.38663342830009495
# accuracy: 0.613366571699905
# preferred_accuracy: 0.643061224489796
# predictions_count: 4900   in 4659
# real prob: 0.5561585653610194

# %%
df = model.predict_last()
df
# Out:
#       NAME            2024-04-23 00:00:00                color_and_value  \
# 0      GJ1  15.16266 | FFFF00 | 279259571  15.16266 | FFFF00 | 279259571
# 1      GJ2  12.20255 | A9D08E | 177719481  12.20255 | A9D08E | 177719481
# 2      GJ3     5.246354 | FFFF00 | 993929     5.246354 | FFFF00 | 993929
# 3      GJ4    3.574794 | FFFF00 | 8903130    3.574794 | FFFF00 | 8903130
# 4      GJ5     13.85017 | A9D08E | 197001     13.85017 | A9D08E | 197001
# ..     ...                            ...                            ...
# 125  GJ132     24.86704 | A9D08E | 459557     24.86704 | A9D08E | 459557
# 126  GJ133    -17.7025 | FFFF00 | 2061010    -17.7025 | FFFF00 | 2061010
# 127  GJ134     16.26354 | FFFF00 | 299488     16.26354 | FFFF00 | 299488
# 128  GJ135    7.504595 | A9D08E | 1200666    7.504595 | A9D08E | 1200666
# 129  GJ136    55.14601 | A9D08E | 4657549    55.14601 | A9D08E | 4657549
#
#      next_color_code
# 0                0.0
# 1                1.0
# 2                0.0
# 3                0.0
# 4                1.0
# ..               ...
# 125              0.0
# 126              0.0
# 127              0.0
# 128              0.0
# 129              0.0
#
# [130 rows x 4 columns]

# %%
print(df[(df['next_color_code'] != 0)  ].shape)
df[(df['next_color_code'] != 0) ]
# Out:
# (78, 4)
#       NAME            2024-04-23 00:00:00                color_and_value  \
# 1      GJ2  12.20255 | A9D08E | 177719481  12.20255 | A9D08E | 177719481
# 4      GJ5     13.85017 | A9D08E | 197001     13.85017 | A9D08E | 197001
# 6      GJ7    26.48245 | FFFF00 | 9410832    26.48245 | FFFF00 | 9410832
# 7      GJ8     32.39655 | FFFF00 | 323734     32.39655 | FFFF00 | 323734
# 8      GJ9     19.98961 | 8EA9DB | 703167     19.98961 | 8EA9DB | 703167
# ..     ...                            ...                            ...
# 115  GJ121    61.92598 | 8EA9DB | 2913512    61.92598 | 8EA9DB | 2913512
# 119  GJ125    63.10754 | A9D08E | 1274812    63.10754 | A9D08E | 1274812
# 120  GJ126   68.56287 | 8EA9DB | 18832015   68.56287 | 8EA9DB | 18832015
# 121  GJ128   26.48168 | 8EA9DB | 19022799   26.48168 | 8EA9DB | 19022799
# 122  GJ129     1.912461 | A9D08E | 269676     1.912461 | A9D08E | 269676
#
#      next_color_code
# 1                1.0
# 4                1.0
# 6                1.0
# 7                1.0
# 8                1.0
# ..               ...
# 115              1.0
# 119              1.0
# 120              1.0
# 121              1.0
# 122              1.0
#
# [78 rows x 4 columns]
